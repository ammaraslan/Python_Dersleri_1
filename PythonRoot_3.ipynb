# %% [markdown]
# # Metinsel Fonksiyonlar

# %% [markdown]
# ***NOT*** : pythonda büyük küçük harf farkı vardır bu herşeyde geçerlidir değişkenler ve metinlerde dahil

# %% [markdown]
# ## Split metodu
#
# ---

# %%
#split metodu spliten sonra gelen parantezde belirtilen yerden cümleleri yada kelimelerli ayırır
adi="Batman Üniversitesi"
print(adi)
print(adi.split(" "))
adi=adi.split(" ")
Adi=adi[0]
print(Adi)
ADi=adi[1]
print(ADi)
# Out:
# Batman Üniversitesi
# ['Batman', 'Üniversitesi']
# Batman
# Üniversitesi

# %%
isim = "BATMAN ÜNİVERSİTESİ TEKNİK BİLİMLER MESLEK YÜKSEKOKULU"
print(isim)
isim = isim.split(" ")
print(isim)
print(isim[2:])
print(isim[:2])
print(isim[::-1])

# %% [markdown]
# ## Upper metodu

# %%
#upper değişkenin bütün harflerini büyültür
adi="Batman Üniversitesi"
print(adi)
print(adi.upper())
# Out:
# Batman Üniversitesi
# BATMAN ÜNIVERSITESI

# %% [markdown]
# ## Lower metodu

# %%
#lower değişkenin bütün harflerini küçültür
adi="Batman Üniversitesi"
print(adi)
print(adi.lower())
# Out:
# Batman Üniversitesi
# batman üniversitesi

# %% [markdown]
# ## title metodu

# %%
# title değişkenin bütün kelimelerin ilk harfini büyük yapar
adi="batman üniversitesi"
print(adi)
print(adi.title())
# Out:
# batman üniversitesi
# Batman Üniversitesi

# %% [markdown]
# ## capitalize

# %%
#capitalize str değişkenin sadece ilk kelimenin sadece baş harfini büyük yazar
adi="Batman üniversitesi"
print(adi)
print(adi.capitalize())
# Out:
# Batman üniversitesi
# Batman üniversitesi

# %% [markdown]
# ## Strip metodud

# %%
#strip metodu değişkenin başındaki ve sonundaki boşlukları siler
adi="****Batman Üniversitesi****"
print(adi)
print(adi.strip("*"))
print(adi.rstrip())
print(adi.lstrip())
adi="______Batman üniversitesi_____"
print(adi)
print(adi.strip("_"))
# strip sonra gelen parantezde ne belirtilirse onları değişkenin başından ve sonundan siler
#rstrip sonundakileri siler
#lstrip başındakileri siler
print(adi.rstrip("_"))
print(adi.lstrip("_"))
# Out:
# ****Batman Üniversitesi****
# Batman Üniversitesi
# ****Batman Üniversitesi****
# ****Batman Üniversitesi****
# ______Batman üniversitesi_____
# Batman üniversitesi
# ______Batman üniversitesi
# Batman üniversitesi_____

# %% [markdown]
# ## replace metodu

# %%
# replace metodu replace sonra gelen parntezde belirtilen ilk özellik yerine ikinci özelliği yazar
metin="batman.edu.tr"
print(metin)
print(metin.replace("batman.edu.tr","https://batman.edu.tr"))
# Out:
# batman.edu.tr
# https://batman.edu.tr

# %% [markdown]
# ## find metodu

# %%
# find metodu belirtilen özelliğin yada kelimenin nerde başladığını yazar
metin="Benim adım Abdulkadir onun adı kadrite ve o ahmet"
print(metin.find("adı"))
print(metin.find("h"))
print(metin.find("adım",10,30))
print(metin.find("z"))
# Out:
# 6
# 45
# -1
# -1

# %% [markdown]
# ## index metodu

# %%
#index metodu find metodu ile aynı işi yapar
metin="my name is ammar she name kadriye he name taha"
print(metin.index("name"))
print(metin.index("h"))
print(metin.index("name",10,30))
# Out:
# 3
# 18
# 21

# %% [markdown]
# ## count metodu

# %%
# count belirtilen özelliğin kaçte olduğunu yazdırır
adi="Batman Üniversitesi"
print(adi.count("a"))
print(adi.count("a",5,10))
# Out:
# 2
# 0

# %% [markdown]
# ## swith metodu

# %%
# startswith değişken belirtilen özellikle başlıyor ise true başlamıyor ise false yazdırır
adi="Abdulkadir zilan ışık"
print(adi.startswith("Abdulkadir"))
print(adi.startswith("abdulkadir"))
#endswith ise değişken belirtilen özelik ile bitiyomu diye bakar
print(adi.endswith("ışık"))
print(adi.endswith("ışıK"))
# Out:
# True
# False
# True
# False

# %% [markdown]
# ## Center
# kelimeye karekter ekleme - kelimlerin sayısını da dahil eder

# %%
adi="Batman"
print(adi.center(100," "))
#center kelimeyi belirtilen uzunlukta ortalar ve sonra başına ve sonun belirtilen özelliği koyar
print(adi.ljust(25,"*"))
print(adi.rjust(25,"*"))
# Out:
#                                                Batman
# Batman*******************
# *******************Batman

# %% [markdown]
# ## Uygulama 1

# %%
isim = "bATMAN üniversiteis TeKnİk BİLİMLER meslek YÜKSEKOKULU"
# print(isim)
# isim = isim.split(" ")
# print(isim)
# print(isim[2:])
# print(isim[:2])
# print(isim[::-1])
print(isim)
print(isim.upper())
print(isim.lower())
print(isim.capitalize())
print(isim.count("A"))
print(isim.title())
print(isim.find("A",0,10))
print(isim.center(100,"*"))
