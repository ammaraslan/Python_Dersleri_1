# %% [markdown]
# # MODÜLLER

# %% [markdown]
# Modüllerde aslında içerisinde faydalı olabilecek sınıfların, fonksiyonların veya değişkenlerin yazıldığı ve sonrasında ihtiyacımız olduğunda kullanabileceğimiz kodlar bütünüdür.Modül içerisinde fonksiyonları, sınıfları veya değişkenleri barındıran bir Python dosyasıdır.

# %% [markdown]
# ***Modülleri projenize çağırıp indirmek ve kullanmak için dört tane yöntem kullanabilirsiniz***
#
#
# ---
#
# * Herhangi bir modülü projemize indirmek ve kullanmak için **import
# math**
# şeklinde çağırabilirsiniz
#
# ---
#
# * Modülleri indirirken kendinizde isim veya kısaltma verebilirsiniz **import math as matematik ya da import math as mt** şeklinde çağırabilirsiniz
#
# ---
#
# * Bir modül içerisinden herhangi bir sınıf veya fonksiyonu kullanmak istediğinizde **from math import sqrt** şeklinde çağırabilirsiniz
#
# ---
#
# * Bir modül içerisindeki her şeyi **from math import** şeklinde çağırabilirsiniz
#
#
# ```
# import math
# import math as ammar
# from math import *
# from math import pow,factorial
# ```

# %% [markdown]
# ## Hazır modüller ve Kullanımı

# %%
#1. Yöntem
import math
math.factorial(5)
# Out:
# 120

# %%
#2. Yöntem
import math as semih
semih.factorial(6)
# Out:
# 720

# %%
#3. Yöntem
from math import factorial,pow,sqrt
factorial(10)
# Out:
# 3628800

# %%
#4. Yöntem
from math import *
factorial(11)
# Out:
# 39916800

# %%
#import datetime
#datetime.datetime.now().year
from datetime import *

import math as semih
print(dir(semih))
# Out:
# ['__doc__', '__loader__', '__name__', '__package__', '__spec__', 'acos', 'acosh', 'asin', 'asinh', 'atan', 'atan2', 'atanh', 'ceil', 'copysign', 'cos', 'cosh', 'degrees', 'e', 'erf', 'erfc', 'exp', 'expm1', 'fabs', 'factorial', 'floor', 'fmod', 'frexp', 'fsum', 'gamma', 'gcd', 'hypot', 'inf', 'isclose', 'isfinite', 'isinf', 'isnan', 'ldexp', 'lgamma', 'log', 'log10', 'log1p', 'log2', 'modf', 'nan', 'pi', 'pow', 'radians', 'remainder', 'sin', 'sinh', 'sqrt', 'tan', 'tanh', 'tau', 'trunc']

# %% [markdown]
# ### Math Modülü
#
# ```
# # dir(math)
# ```
# Fonksiyon	Tanımı
# * ceil(x)	X değerine eşit veya daha büyük en küçük tamsayıyı döndürür.
#
# ---
#
#
# * copysign(x, y)	X’i y işareti ile döndürür
# ---
#
# * abs(x)	X’in mutlak değerini döndürür
# ---
# * factorial(x)	X faktöriyelini verir
# ---
# * floor(x)	X değerine eşit veya daha küçük en büyük tamsayıyı döndürür
# ---
# * fmod(x, y)	X, y ile bölündüğünde kalanını döndürür
# ---
# * frexp(x)	Mantis ve x’in üssünü çift (m, e) olarak döndürür
# ---
# * fsum(iterable)	Yinelenebilir değerdeki doğru kayan nokta toplamını döndürür
# ---
# * isfinite(x)	X ne bir sonsuzluk ne de bir NaN (Sayı Değil) ise True değerini döndürür
# ---
# * isinf(x)	X pozitif veya negatif bir sonsuzsa True değerini döndürür
# ---
# * isnan(x)	X bir NaN ise True döndürür
# ---
# * ldexp(x, i)	X * (2 ** i) değerini döndürür
# ---
# * modf(x)	X’in kesirli ve tamsayı kısımlarını döndürür
# ---
# * trunc(x)	X’in kesilmiş tam sayı değerini döndürür
# ---
# * exp(x)	E ** x döndürür
# ---
# * expm1(x)	E ** x – 1 değerini döndürür
# ---
# * log(x[, base])	X’in logaritmasını tabana döndürür (varsayılan olarak e’dir)
# ---
# * log1p(x)	1 + x’in doğal logaritmasını verir
# ---
# * log2(x)	X’in base-2 logaritmasını verir
# ---
# * log10(x)	X’in base-10 logaritmasını verir
# ---
# * pow(x, y)	Y gücüne yükseltilmiş x değerini döndürür
# ---
# * sqrt(x)	X’in karekökünü döndürür
# ---
# * acos(x)	X’in ark kosinüsünü verir
# ---
# * asin(x)	X’in ark sinüsünü döndürür
# ---
# * atan(x)	X’in ark tanjantını verir
# ---
# * cos(x)	X’in kosinüsünü verir
# ---
# * hypot(x, y)	Öklid normu, sqrt (x * x + y * y) döndürür
# ---
# * sin(x)	X’in sinüsünü döndürür
# ---
# * tan(x)	X tanjantını verir
# ---
# * degrees(x)	X açısını radyandan dereceye dönüştürür
# ---
# * radians(x)	X açısını dereceden radyana dönüştürür
# ---
# * acosh(x)	X’in ters hiperbolik kosinüsünü verir
# ---
# * asinh(x)	X’in ters hiperbolik sinüsünü döndürür
# ---
# * atanh(x)	X’in ters hiperbolik tanjantını verir
# ---
# * cosh(x)	X’in hiperbolik kosinüsünü verir
# ---
# * sinh(x)	X’in hiperbolik kosinüsünü verir
# ---
# * tanh(x)	X’in hiperbolik tanjantını verir
# ---
# * erf(x)	X konumunda hata işlevini döndürür
# ---
# * erfc(x)	X değerinde tamamlayıcı hata işlevini döndürür
# ---
# * gamma(x)	X değerinde Gama işlevini döndürür
# ---
#  * lgamma(x)	X’deki Gama işlevinin mutlak değerinin doğal logaritmasını döndürür
# ---
# * pi	Matematiksel sabit, bir dairenin çevresinin çapına oranı (3.14159 …)
# ---
# * e	matematiksel sabit e (2.71828 …)

# %%
from math import * 
#dir(math)
us=pow(2,3)
kok=sqrt(16)
fakt=factorial(9)
sin=sin(45)
print(f"Üstü {us} kökü {kok} fakt {fakt} sin {sin}")
# Out:
# Üstü 8.0 kökü 4.0 fakt 362880 sin 0.8509035245341184

# %% [markdown]
# ---

# %% [markdown]
# ### OS Modülü
# [Kaynak](https://medium.com/python/python-os-mod%C3%BCl%C3%BC-a699a681c734)

# %%
from os import *
#name "İşletim sistemi bilgisini verir"
print(name)
#getcwd  "O an içinde bulunduğumuz klasörü göstermektedir" 
print(getcwd())
#system "Cmd komutu gibi çalışır"
#system("pip install numpy")
#system("tree")
#chdir os.chdir() ile (change directory) farklı bir klasör içerisine geçebilirsiniz. İlk önce getcwd() ile nerde olduğuma bakarız daha sonra chdir() ile Documents klasörüne geçiş yaparız. Tekrar getcwd() ile Documents klasöründe olduğumu doğruladım.
chdir("/content/drive/MyDrive/Batman Üniversitesi/Ders Notları")
print(getcwd())
listdir()

# %% [markdown]
# ---

# %% [markdown]
# * mkdir()
# * Eğer bulunduğunuz klasör içerisinde yeni bir klasör oluşturmak isterseniz
# os.mkdir() methodunu kullanıyoruz.
# * mkdir("DENEME-MKDİR")
# * Eğer dizini o anda içinde bulunduğunuz dizin içinde değil de farklı bir konumda oluşturmak isterseniz, o konumun açık adresini belirtebilirsiniz:
# * os.mkdir('/home/farkliadres/Desktop/yeniklasor')

# %%
#mkdir()
#Eğer bulunduğunuz klasör içerisinde yeni bir klasör oluşturmak isterseniz 
#os.mkdir() methodunu kullanıyoruz.
#mkdir("DENEME-MKDİR")
#Eğer dizini o anda içinde bulunduğunuz dizin içinde değil de farklı bir konumda oluşturmak isterseniz, o konumun açık adresini belirtebilirsiniz:
# os.mkdir('/home/farkliadres/Desktop/yeniklasor')
# Out:
# /content/drive/MyDrive/Batman Üniversitesi/Ders Notları/Python Derslerim

# %% [markdown]
# * Uyarı : Eğer oluşturmaya çalıştığınız dizin zaten varsa os.mkdir() hata verecektir:

# %% [markdown]
# > Bu doyanın bulunduğu dizine "OS Uygulamaları" adında bir klasör açınız.

# %%
#Uygulama: Bu doyanın bulunduğu dizine OS Uygulamaları adında bir klasör açınız.
chdir("/content/drive/MyDrive/Batman Üniversitesi/Ders Notları/Python Derslerim")
print(getcwd())
listdir()
if(not path.exists("OS Modül Uygulamaları")):
  mkdir("OS Modül Uygulamaları")
listdir()
rename("OS Modül Uygulamaları","OS Modülü")
# Out:
# /content/drive/MyDrive/Batman Üniversitesi/Ders Notları/Python Derslerim

# %% [markdown]
# rmdir()
#  * İçi boş olan bir klasörü silmek için kullanılır, az önce oluşturduğumuz yeniKlasor isimli dizini silelim.
#   * Eğer silmeye çalıştığınız dizin içinde herhangi bir başka dizin veya dosya varsa bu fonksiyon hata verecektir.

# %%
getcwd()
chdir("/content/drive/MyDrive/Batman Üniversitesi/Ders Notları/Python Derslerim")
if(path.exists("OS Modülü")):
  rmdir("OS Modülü")

# %% [markdown]
# stat()
#  * Herhangi bir dosyanın boyutu, değiştirilme tarihi gibi bilgileri döndürür.

# %%
stat("PythonRoot_1.ipynb")
# Out:
# os.stat_result(st_mode=33152, st_ino=49, st_dev=42, st_nlink=1, st_uid=0, st_gid=0, st_size=8009, st_atime=1638300955, st_mtime=1637750529, st_ctime=1637750529)

# %% [markdown]
# walk():
#  * Verdiğiniz bir klasörün altındaki dizinleri ve dosyaları görebileceğiniz bir method.

# %%
for i in walk("/content/drive/MyDrive/"):
  print(i)

# %% [markdown]
# path():
#  * Bir dosya ve klasörün var olup olmadığını kontrol etmek istediğinizde path.exists() methodunu kullanabilirsiniz.
#
# Verdiğiniz parametrenin bir dizin mi yoksa dosya mı olduğunu da sorgulayabilirsiniz.
#  * Bunun için ise **path.isdir()** ve **path.isfile()** methodlarını kullanıyoruz.

# %%
path.exists("/content")
# Out:
# True

# %% [markdown]
# ### Date Modülü

# %%
from datetime import * 
print(datetime.now().year)
# Out:
# 2021

# %% [markdown]
# ## Kendi oluşturduğumuz modüller

# %% [markdown]
# ### Üçgen Modülü Oluşturma

# %%
from os import *
print(getcwd())
chdir("/content/drive/MyDrive/Batman_Üniversitesi/Ders_Notları/Python Derslerim/")
# Out:
# /content/drive/My Drive/Batman_Üniversitesi/Ders_Notları/Python Derslerim

# %%
import ucgen

# %%
print(ucgen.isim)
print(ucgen.pi)
print(ucgen.AlanHesapla(1,2))
# Out:
# Ammar ASLAN
# 3.14
# 1.0

# %%
import kup

print(kup.KureHacim(9))
print(kup.KureAlan(9))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-11-101f0df5d9cc> in <module>()
# ----> 1 import kup
#       2
#       3 print(kup.KureHacim(9))
#       4 print(kup.KureAlan(9))
#
# ModuleNotFoundError: No module named 'kup'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
