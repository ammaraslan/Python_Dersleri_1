# %% [markdown]
# # İlk Ders İlk Uygulama

# %%
print("Merhaba Dünya")
print(2+5)
print("Abdulkadir Zilan Işık Notu:",100)
# Out:
# Merhaba Dünya
# 7
# Abdulkadir Zilan Işık Notu: 100

# %% [markdown]
# ## Veri Tipleri

# %%
a = 5
b=5.5
c="Ammar" 
d = False
print(a)
print(type(a))
print(b)
print(type(b))
print(c)
print(type(c))
print(d)
print(type(d))
# Out:
# 5
# <class 'int'>
# 5.5
# <class 'float'>
# Ammar
# <class 'str'>

# %% [markdown]
# ## Print Komutu

# %%
print("Batman","Üniversitesi",sep="*")
print("Batman","Üniversitesi",sep=" - ")
# Out:
# Batman*Üniversitesi
# Batman - Üniversitesi

# %%
print("Ammar ASLAN")

# %% [markdown]
# ## Değişken Atama

# %%
yas=30
cinsiyet="erkek"
boy=1.83
kilo=103
print("Merhaba yaşım:",yas,"Cinsiyetim:",cinsiyet,"Boyum:",boy,"Kilom",kilo)
# Out:
# Merhaba yaşım: 30 Cinsiyetim: erkek Boyum: 1.83 Kilom 103

# %%
ocak=mart=mayis=temmuz=agustos=ekim=aralik = 31
subat=28
nisan=haziran=eylul=kasim =30

# %%
print(eylul)
# Out:
# 30

# %% [markdown]
# ## Yasaklı Değişken Adı Kelimeleri

# %%
import keyword

# %%
#@title Varsayılan başlık metni
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %% [markdown]
# ## Karekter işlemleri

# %%
sayi = 3
ad="ammar"
soyad="aslan"
print(ad,soyad)
print(ad+soyad)
print(ad*sayi)
# Out:
# ammar aslan
# ammaraslan
# ammarammarammar

# %%
print("ammar\naslan")
print("ammar\taslan")
print("\u0061")
# Out:
# ammar
# aslan
# ammar	aslan
# a

# %% [markdown]
# ## Uygulama 1 - Sınav Sorusu
#
#
# ```
# # 1-) Kullanıcıdan isim, soyisim, ve doğum tarihi bilgilerini alıp ekrana “Merhaba Ammar ASLAN yaşınız 40 Hoş Geldiniz”
# şeklinde çıktı veren python kodunu yazınız. (20p).
# ```

# %%
import datetime
isim  ="Ammar"
soyisim = "Aslan"
dogumTarihi = datetime.datetime.now().year
yas = 2021 - dogumTarihi
print("Merhaba", isim,soyisim,"yaşınız ",yas,"Hoş Geldiniz")
# Out:
# Merhaba Ammar Aslan yaşınız  0 Hoş Geldiniz
