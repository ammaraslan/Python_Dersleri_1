# %% [markdown]
# # ***Python'da Metotlar***
#
#
# ```
# # Fonksiyon tanımlamak için def komutunu kullanıyoruz.
# ```

# %% [markdown]
# ## Fonksiyon tanımlamak

# %%
def MerhabaDe():
  print("Merhaba Fonksiyon 1")

# %% [markdown]
# ## Fonksiyon çağırmak

# %%
MerhabaDe()
# Out:
# Merhaba Fonksiyon 1
# Merhaba Fonksiyon 2

# %% [markdown]
# ## Fonksiyona Parametre Gönderme

# %%
def Topla(sayi1, sayi2):
  print(sayi1+sayi2)

# %%
Topla(6,7)
# Out:
# 13

# %% [markdown]
# ## Fonksiyondan Geriye Bilgi Gönderme

# %%
def Cikarma(sayi1,sayi2):
  sonuc = sayi1-sayi2
  return sonuc

# %%
Fark = Cikarma(10,9)
print(Fark)
# Out:
# 1

# %% [markdown]
# ## Uygulama 1
#
#
# ```
# # Klavyeden girilen 2 sayıdan büyük olanı ekrana yazan geri bildirimli kodu yazın.
# ```

# %%
def BuyukBul(sayi1,sayi2):
  if sayi1>sayi2:
    return sayi1
  elif sayi2>sayi1:
    return sayi2
  else:
    return 0

deger1  = int(input("Lütfen Birinci Sayıyı Giriniz"))
deger2  = int(input("Lütfen İkinci Sayıyı Giriniz"))

sonuc = BuyukBul(deger1,deger2)

if sonuc==0:
  print("Değerler Eşittir")
else:
  print("Büyük Olan Sayı: ",sonuc)
# Out:
# Lütfen Birinci Sayıyı Giriniz5
# Lütfen İkinci Sayıyı Giriniz6
# Büyük Olan Sayı:  6

# %% [markdown]
# ## Uygulama 2 - Ödev
#
#
# ```
# Gönderilen 2 sayı arasındaki tüm asal sayıları bulan python fonksiyon uygulamasını yapınız.
# ```

# %%
def AsalBul(bas,bit):
  for i in range(bas,bit):

# %% [markdown]
# ## Uygulama 3
#
# ```
# # Faktöriyel Hesaplaması yapan fonksiyonu yazınız.
# ```

# %%
def FaktoriyelHesapla(faktoriyel):
  sonuc=1
  for i in range(faktoriyel,1,-1):
    sonuc=i*sonuc
  return sonuc

print(FaktoriyelHesapla(3))
# Out:
# 6

# %% [markdown]
# ## Recursive (Özyineli) Fonksiyonlar

# %% [markdown]
# Recursive fonksiyonlar kendi kendini çağıran fonksiyonlardır. Kısaca bir döngü gibi düşünebiliriz burada dikkat etmemiz gereken şey sonsuz döngüye girmemesi için bir şart koşulu kullanmalıyız.

# %% [markdown]
# ## Uygulama 1
#
#
#
# ```
# # Girilen indiste fibonacci değerini bulan özyinelemeli fonksiyonu yazınız.
# ```

# %%
# 0,1,1,2,3,5 ......
def fibonacci(sayi):
    if sayi==0:
        return 0
    if sayi==1:
        return 1
    return fibonacci(sayi-1) + fibonacci(sayi-2)

sayi=int(input("Bir sayi girin :"))
print(fibonacci(sayi))
# Out:
# Bir sayi girin :5
# 5
