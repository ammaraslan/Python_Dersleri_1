# %% [markdown]
# # **Tip Tönüşümleri** , **Karmaşık** **Sayılar**

# %% [markdown]
# ## STR

# %%
a = 5
a= str(a);
print(a+"ammar")
print(type(a))
# Out:
# 5ammar
# <class 'str'>

# %% [markdown]
# ##INT

# %%
yas="5"
print(yas)
print(type(yas))
iyas=int(yas)
print(iyas)
print(type(iyas))
# Out:
# 5
# <class 'str'>
# 5
# <class 'int'>

# %% [markdown]
# ## FLOAT

# %%
b = 22
print(b)
print(type(b))
b=float(b)
print(b)
print(type(b))
# Out:
# 22
# <class 'int'>
# 22.0
# <class 'float'>

# %%
sayi ="5"
sayi = int(sayi)
print(type(sayi))
# Out:
# <class 'int'>

# %% [markdown]
# ## LEN - Uzunluk

# %%
a = "Ammar ASLAN"
b = "125"
print("a için Uzunluk: ",len(a))
print("b için Uzunluk: ",len(b))
# Out:
# a için Uzunluk:  11
# b için Uzunluk:  3

# %% [markdown]
# ## Yorum Satırları

# %%
"""
çok satırlı yorum satırı
"""
#Yorum satırı 2

# %% [markdown]
# ## Örnek Uygulama 1

# %%
isim = "Ammar"
soyisim = "Aslan"
bolum = "Bilgisayar Teknolojileri Programı"
numara = "124454854545"
#print(isim,soyisim,bolum,numara)
print(*bolum,sep="_")
# Out:
# B_i_l_g_i_s_a_y_a_r_ _T_e_k_n_o_l_o_j_i_l_e_r_i_ _P_r_o_g_r_a_m_ı

# %% [markdown]
# ## Örnek Uygulama 2

# %%
isim = "Ammar ASLAN"

gidis_Ucreti = 1.55
gelis_Ucreti = 1.55

gider = (gidis_Ucreti+gelis_Ucreti)*20
print(isim,"günde ",gidis_Ucreti+gelis_Ucreti,"TL'den 20 günde Aylık yol masrafı", gider," TL'dir" )
# Out:
# Ammar ASLAN günde  3.1 TL'den 20 günde Aylık yol masrafı 62.0  TL'dir

# %% [markdown]
# ## Örnek Uygulama 3

# %%
import datetime

dTarihi = 1988
yil = datetime.datetime.now().year
yas = yil - dTarihi
print(yas)
# Out:
# 33

# %% [markdown]
# ## Karmaşık Sayılar

# %%
compleks  = 8j
print(compleks)
# Out:
# 8j

# %% [markdown]
# ## Kullanıcıdan Veri Girişi

# %% [markdown]
# Klavyeden veri Giriş İnput kullanılır. İnput değer olarak str döner. Eğer metinsel işlem değilde hesaplama yapılacaksa o zaman tip dönüşümü uygulanmalıdır.

# %%
sayi1 = int(input("Lütfen Birinci Sayıyı Giriniz"))

sayi2 = int(input("Lütfen İkinci Sayıyı Giriniz"))

toplam = sayi1 + sayi2

print("Toplam Değer", toplam)

# %%
import datetime
dTarihi = int(input("Lütfen Doğum Tarihinizi Yıl Olarak Giriniz"))
BuYil = datetime.datetime.now().year
print(BuYil-dTarihi)
# Out:
# Lütfen Doğum Tarihinizi Yıl Olarak Giriniz1997
# 24

# %%
yas = input("Yaşınızı Giriniz")
print(yas)
# Out:
# Yaşınızı Giriniz20
# 20

# %% [markdown]
# ## Rasgele Rayı Üretme
# (Random Number)

# %%
import random
print(random.randrange(0,100))
# Out:
# 64

# %%
import random as r

sayi = r.randrange(0,100)
print(sayi)
# Out:
# 76

# %%
import random as r

b=r.randrange(0,11)
i=r.randrange(0,11)
u=r.randrange(0,11)
d=r.randrange(0,11)
be=r.randrange(0,11)

print("Kanazan ",b,i,u,d,be)
# Out:
# Kanazan  2 0 10 4 10

# %% [markdown]
# ### Uygulama 1 - Dairenin Alanı ve Çevresi - Sınav Sorusu

# %%
  yaricap  = int(input("Dairenin yarıçapını giriniz..."))
  Alan = yaricap*yaricap*3.14
  print("Dairenin Alanı: ",Alan)

  Cevre = 2*yaricap*3.14
  print("Dairenin Çevresi: ",Cevre)
# Out:
# Dairenin yarıçapını giriniz...3
# Dairenin Alanı:  28.26
# Dairenin Çevresi:  18.84

# %% [markdown]
# ### Uygulama 2 - Genel Not Hesaplama - Sınav Sorusu

# %%
  vize = int(input("Vize Notunuzu Giriniz"))
  final = int(input("Final Notunuzu Giriniz"))
  notu = (vize*40/100) + (final *60/100)
  print(notu)

# %% [markdown]
# ## Aritmetik Operatörler

# %% [markdown]
# ### Toplama Operatörü (+)

# %%
x=5
y=10
z=x+y
print(z)
# Out:
# 15

# %% [markdown]
# ### Çıkarma Operatörü (-)

# %%
x=9
y=10
z=x-y
print(z)
# Out:
# -1

# %% [markdown]
# ### Çarpma Operatörü (*)

# %%
carpma = (x+y)*(x-y)
print(carpma)
# Out:
# 0

# %% [markdown]
# ### Bölme Operatörü (/)

# %%
bolme = (x+y)/(x-y)
print(bolme)
# Out:
# -19.0

# %% [markdown]
# ### Mod Operatörü (%)

# %%
Mod = 9%2
print(Mod)
# Out:
# 1

# %% [markdown]
# ### Tam Bölme Operatörü (//)

# %%
TB = 7//3
print(TB)
# Out:
# 2

# %% [markdown]
# ### Üs Alma Operatörü (**)

# %%
us = 7**2
print(us)

ust = pow(7,2)
print(ust)
# Out:
# 49
# 49

# %% [markdown]
# ### Yuvarlama Operatörü (round)

# %%
deger = 7.55454
print(round(deger))
# Out:
# 8

# %% [markdown]
# ##  Karşılaştırma Operatörler

# %%
a = 5
b = 5
print(a==b) #Eşittir
print(a!=b) #Eşit değildir
print(a<=b)
print(a<b)
print(a>=b)
print(a>b)
# Out:
# True
# False
# True
# False
# True
# False

# %% [markdown]
# ##  Mantıksal Operatörler

# %%
a = 5
b = 5
c = 6
d = 7
print(a==b or c==d)
print(a==b and c==d)
print(not(5==5))
# Out:
# True
# False
# False

# %% [markdown]
# ### Uygulama 1 - Aralık İnceleme

# %%
#Girilen sayının 0 - 100 arasında olup olmadığını bulun programı yazınız.

deger = int(input("0 ile 100 arasında bir değer giriniz!"))

print(deger>=0 and deger<=100)
# Out:
# 0 ile 100 arasında bir değer giriniz!50
# True

# %% [markdown]
# ### Uygulama 2 - Not Hesaplama

# %%
#Vize ve Final Notlarını Kullanıcıdan 
#Alıp Kişinin geçip geçmediğini söyleyen programı yazınız.
#Kurallar 1: Final 60 'dan büyük eşit olacak
#Kurallar 2: Genel ortalama 60 'dan büyük eşit olacak

vize = int(input("Vize Notunu Giriniz"))
final = int(input("Final Notunuz Giriniz"))

gno = round(vize * 4/10 + final * 6/10)

print(final >= 60 and gno>=60,gno)
# Out:
# Vize Notunu Giriniz02
# Final Notunuz Giriniz98
# True 60

# %% [markdown]
# ### Uygulama 3 - Login - Giriş

# %%
#k.adı: ammaraslan
#şifre: 123456

kadi  = input("Kullanıcı Adı Giriniz")
sifre = input("Şifre Giriniz")

print(kadi=="ammaraslan" and sifre =="123456")
# Out:
# Kullanıcı Adı Girinizammaraslan
# Şifre Giriniz123456
# True

# %% [markdown]
# ### Uygulama 4 - En küçük bulma - Sınav Sorusu

# %%
#yarıçapı girilen dairenin çevresini hesaplayan programı yazınız. (2*Pİ*R)

yaricap = int(input("Yarıçapı Giriniz"))
cevre = 2*3.14*yaricap
print(cevre)
# Out:
# Yarıçapı Giriniz5
# 31.400000000000002

# %% [markdown]
# ##  Değer Atama Operatörleri

# %%
ahmet_yas  = 25

'''
print(ahmet_yas)
i = 2
print(i)
'''
i = 1
i = i + 1
print(i)
i+=1
print(i)
i-=1
print(i)
i*=2
print(i)
i/=2
print(i)
i=20
#Mod Almak için kullanılır %
i%=3
print(i)
# Out:
# 2
# 3
# 2
# 4
# 2.0
# 2

# %% [markdown]
# ##  Aitlik Kimlik Operatörleri

# %%
#aitlik
isim ="ahmet"
kontrol  = "ah" in isim
print(kontrol)
#kimlik
id(isim)
# Out:
# True
# 140403119251184

# %% [markdown]
# ---
#
#
# ## **Koşullu İfadeler**  - IF
#
#
# ---

# %%
if 0>1:
  print("doğru")
print("Muhammed Taha")
# Out:
# Muhammed Taha

# %%
# if(koşul):
#     işlem
# if(koşul):
#     işlem1
# elif(koşul2):
#     işlem2
# else:
#     işlem3

#girilen bir sayının negatif mi yoksa pozitifmi yoksa sıfır mı olduğunu ulan programı yazınız

# %% [markdown]
# ### Uygulama 1 - Pozitif, Negatif Kontrolü

# %%
sayi = int(input("Sayı Giriniz"))
if sayi>0:
  print("sayi pozitif")
elif sayi<0:
  print("Sayı Negatif")
else:
  print("Sayı Sıfırdır")
# Out:
# Sayı Giriniz-8
# Sayı Negatif

# %% [markdown]
# ### Uygulama 2 - Büyük Sayıyı Bulma

# %%
sayi1 = int(input("Birinci Sayıyı Giriniz"))
sayi2 = int(input("İkinci Sayıyı Giriniz"))

if sayi1>sayi2:
  print("Birinci Sayı Daha Büyük")
elif sayi2>sayi1:
  print("İkinci Sayı Daha Büyüktür")
else:
  print("Sayılar Eşittir")
# Out:
# Birinci Sayıyı Giriniz5
# İkinci Sayıyı Giriniz6
# İkinci Sayı Daha Büyüktür

# %% [markdown]
# ### Uygulama 3 - Büyük Sayıyı Bulma

# %%
sayi1 = int(input("Birinci Sayıyı Giriniz"))
sayi2 = int(input("İkinci Sayıyı Giriniz"))
sayi3 = int(input("üçüncü Sayıyı Giriniz"))
if sayi1>sayi2 and sayi1>sayi3 :
  print("en büyük sayı 1 sayıdır")
elif sayi2>sayi1 and sayi2>sayi3:
   print("en büyük sayı 2 sayıdır")
elif sayi3>sayi1 and sayi3>sayi2 :
   print("en büyük sayı 3 sayıdır")
else:
   print("sayılar bir birine eşiittir")
# Out:
# Birinci Sayıyı Giriniz70
# İkinci Sayıyı Giriniz70
# üçüncü Sayıyı Giriniz70
# sayılar bir birine eşiittir

# %% [markdown]
# ### Uygulama 4 - Hesap Makinası

# %%
sayi1 = int(input("Birinci Sayıyı Giriniz"))
sayi2 = int(input("İkinci Sayıyı Giriniz"))
islem = input("Lütfen Yapmak istediğiniz işlemin kodunu giriniz. Ör: +,-")

if sayi1>=sayi2:
  buyuk=sayi1
  kucuk=sayi2
else:
  buyuk=sayi2
  kucuk=sayi1

if islem=="+":
  print(buyuk+kucuk)
elif islem=="-":
  print(buyuk-kucuk)
elif islem=="*":
  print(buyuk*kucuk)
else:
  print(buyuk/kucuk)
# Out:
# Birinci Sayıyı Giriniz5
# İkinci Sayıyı Giriniz20
# Lütfen Yapmak istediğiniz işlemin kodunu giriniz. Ör: +,-/
# 4.0

# %% [markdown]
# ### Uygulama 5 - Not Hesaplama Uygulaması

# %%
#Final Notu 60 büyük ve GNO 60 ise Geçti aksi
# halde kaldı yazan programı yazın(GNo=vize*0,4+Final*0,6).
#Kullanıcıdan vize ve final notunu alan
# ve yukardaki şartlara göre hesaplayan programı yazınız.

vize  = int(input("Vize Notunuzu Giriniz"))
final = int(input("Final Notunuzu Giriniz"))
GNO= round(vize*0.4+final*0.6)
if(vize<0 or final<0):
  print("Vizeniz veya Finaliniz Sıfırdan Küçük Olamaz LütfenTekrar Deneyin")
else:
  if final>=60 and GNO>=60:
    print("Geçtiniz", "Notunuz: ",GNO)
  else: 
    if(GNO<60 and final<60):
      print("Kaldınız çünkü Final 60'dan küçük ve GNO 60'dan küçük ", "Final Notunuz: ",Final,"NO Notunuz: ",GNO)
    elif(final<60):
      print("Kaldınız çünkü Final 60'dan küçük ", "Final Notunuz: ",Final)
    else: 
      print("Kaldınız çünkü GNO 60'dan küçük ", "Notunuz: ",GNO)
# Out:
# Vize Notunuzu Giriniz02
# Final Notunuzu Giriniz98
# Geçtiniz Notunuz:  60

# %% [markdown]
# ### Uygulama 6 - Girilen sayının tek mi yoksa çiftmi olduğunu bulan programı yazınız

# %%
sayi1 = int(input("Sayıyı Giriniz"))
if(sayi1%2==0):
    print("Sayı Çiftir")
else:
    print("Sayı Tektir")

# %% [markdown]
# ### Uygulama 7 - Girilen sayı değerine göre haftanın günün bulan programı yazınız.

# %%
HaftaninGunu = int(input("Lütfen Haftanın Gününü Giriniz"))
if(HaftaninGunu==1):
    print("Pazartesi")
elif(HaftaninGunu==2):
    print("Salı")
elif(HaftaninGunu==3):
    print("Çarşamba")
elif(HaftaninGunu==4):
    print("Perşembe")
elif(HaftaninGunu==5):
    print("Cuma")
elif(HaftaninGunu==6):
    print("Cumartesi")
elif(HaftaninGunu==7):
    print("Pazar")
else:
    print("Yanlış bir seçim yaptınız",sep=" ")

# %% [markdown]
# ### Uygulama 8 - Askerlik Uygulaması

# %%
#Yaşı 20 büyük ve cinsiyeti erkek olan bir kişinin askere gidip 
#gidemediğiniz bildiren programı yazınız
#Yaş ve cinsiyet klavyeden girilecek
yas=int(input("Lütfen Yaşınızı Giriniz"))
print\
("""
Erkek: E veya e, 
Kadın: K
""")
cinsiyet=input("Lütfen Cinsiyetinizi Giriniz")
if yas>=20 and (cinsiyet=="E" or cinsiyet=="e"):
  print("Gidebilir")
else:
  print("Gidemez")
# Out:
# Lütfen Yaşınızı Giriniz20
#
# Erkek: E veya e,
# Kadın: K
#
# Lütfen Cinsiyetinizi Girinize
# Gidebilir

# %% [markdown]
# # **Döngüler İfadeler**

# %% [markdown]
# ## While

# %% [markdown]
# ### **While** ..iken, ..dığı sürece

# %%
# while(koşul):
#     yapılacalişlem
i = 0
while(i<10):
    print("Ammar")
    i+=1

# %%
i=0
while i<10:
  print(i)
  i=i+1

# %%
#Sonsuz Döngü
i=0
while True:
  print(i)
  i=i+1
  if i>10:
    break

# %% [markdown]
# Uygulama 1: Çift Sayıları Bulan Program

# %%
#1-100 olan çift sayıları ekrana yazan programı yazınız.
i=0
while i<=100:
  print(i)
  i=i+2

# %% [markdown]
# Uygulama 2: İki sayı arasındaki Çift Sayıları Bulan Program - Sınav Sorusu

# %%
sayi1  = int(input("Sayı 1 giriniz"))
sayi2  = int(input("Sayı 2 giriniz"))

while sayi2>=sayi1:
  if sayi1%2 ==0:
    print(sayi1)
  sayi1=sayi1+1
# Out:
# Sayı 1 giriniz30
# Sayı 2 giriniz50
# 30
# 32
# 34
# 36
# 38
# 40
# 42
# 44
# 46
# 48
# 50

# %% [markdown]
# Uygulama 3: Girilen Sayının Faktöriyelini Hesaplayan Program

# %%
Fak  = int(input("Faktöriyelini Hesaplamak İstediğiniz Sayıyı Giriniz:"))
sonuc = 1
while Fak>=1:
  sonuc = sonuc* Fak
  Fak=Fak-1
print(sonuc)
# Out:
# Faktöriyelini Hesaplamak İstediğiniz Sayıyı Giriniz:8
# 40320

# %% [markdown]
# Uygulama 4: 100 defa ismi ekrana yazan program

# %%
isim=input("İsminizi Giriniz")
i=0
while i<=10:
  print(isim,i)
  i=i+1

# %% [markdown]
# Girilen rakam rasgele sayıya eşit ise bunu ekrana yazan programı yazınız.

# %%
import random as r
sayirasgele = r.randrange(0,10)
giris = int(input("Lütfen bir rakam giriniz"))
i=1
while(giris !=sayirasgele  ):
    print("Tekrar Dene ", "Deneme Sayın=", i)
    i+=1
    giris = int(input("Lütfen bir rakam giriniz"))

print("Tebrikler Buldunuz","Deneme Sayınız=",i)

# %% [markdown]
# ## For

# %% [markdown]
# For Döngüsü: için in ise içinde

# %%
# 0 - 10 arasındaki ekrana yazan program

for i in range(0,10,1):
    print(i)

# %%
# 0 - 10 arasındaki tek sayıları yazan program

for i in range(1,10,2):
    print(i)

# %%
# 0 - 10 arasındaki çift sayıları yazan program

for i in range(0,10,2):
    print(i)

# %%
isim ="Ammar"
for kelime in isim:
  print(kelime)
print(isim[3])
# Out:
# A
# m
# m
# a
# r
# a

# %%
for i in range(0,10,2):
  print(i)
# Out:
# 0
# 2
# 4
# 6
# 8

# %%
#girilen iki değer arasındaki çift sayıları bulan programı yazınız

giris = int(input("Başlangıcı Yazınız"))
bitis = int(input("Bitişi Yazınız"))
if(giris%2==0):
    for i in range(giris,bitis,2):
        print(i)
else:
    for i in range(giris+1,bitis,2):
        print(i)

# %% [markdown]
# ### BREAK

# %% [markdown]
# break: döngüyü bitirir

# %%
i=0
while True:
  print("Merhaba Dünya")
  if i==5:
    break
  i=i+1
# Out:
# Merhaba Dünya
# Merhaba Dünya
# Merhaba Dünya
# Merhaba Dünya
# Merhaba Dünya
# Merhaba Dünya

# %%
#Harf Bulma Oyunu
i=1
while True:
  giris=input("Harf Giriniz")
  if giris=="x":
    break
  i=i+1
print(" Tebrikler",i,"Denemenizde Buldunuz.")
# Out:
# Harf Giriniz5
# Harf Giriniz5
# Harf Giriniz1
# Harf Giriniz2
# Harf Girinizxü
# Harf Girinizx
#  Tebrikler 6 Denemenizde Buldunuz.

# %%
#aşağıdaki kodun sonucunu yazınız
for i in range(0,10,1):
    if(i==3):
        break
    print(i)
print("Döngü Bitti")

# %% [markdown]
# ### Continue

# %% [markdown]
# continue: döngü başına gönderir

# %%
i=0
while i<5:
  i=i+1
  print("Semih")
  continue
  print("Ahmet")
# Out:
# Semih
# Semih
# Semih
# Semih
# Semih

# %%
#aşağıdaki çıktı sonucu nedir
for i in range(0,100,1):
    print(i)
    if(i==10):
        continue

# %% [markdown]
# # **Karekter Dizileri**

# %% [markdown]
# #Liste Gibi davranır
#
#
# ```
# isim = "Ammar"
# print(isim[0])
# ```

# %%
#Parçalı işlemler
isim = "Batman Üniversitesi"
print(isim[0:3])
# Out:
# Bat

# %%
isim = "Batman Üniversitesi"
print(isim[1:3])
# Out:
# at

# %%
isim = "Batman Üniversitesi"

print(isim[6])
print(isim[-1])
print(isim[-2])
print(isim[-11])
print(isim[-5:-1:2])
print(isim[0:-1:2])

for i  in isim:
    print(i)
# Out:
# A
# N
# A
# A

# %% [markdown]
# ## LEN - UZUNLUK

# %%
deger = "123456789"
print(len(deger))
# Out:
# 9

# %%
deger = "BATMAN ÜNİVERSİTESİ"
for x in range(len(deger)):
  print(deger)
# Out:
# BATMAN ÜNİVERSİTESİ
# BATMAN ÜNİVERSİTESİ
# BATMAN ÜNİVERSİTESİ
# BATMAN ÜNİVERSİTESİ
# BATMAN ÜNİVERSİTESİ
# BATMAN ÜNİVERSİTESİ
# BATMAN ÜNİVERSİTESİ
# BATMAN ÜNİVERSİTESİ
# BATMAN ÜNİVERSİTESİ
# BATMAN ÜNİVERSİTESİ
# BATMAN ÜNİVERSİTESİ
# BATMAN ÜNİVERSİTESİ
# BATMAN ÜNİVERSİTESİ
# BATMAN ÜNİVERSİTESİ
# BATMAN ÜNİVERSİTESİ
# BATMAN ÜNİVERSİTESİ
# BATMAN ÜNİVERSİTESİ
# BATMAN ÜNİVERSİTESİ
# BATMAN ÜNİVERSİTESİ

# %%
deger = "BATMAN ÜNİVERSİTESİ"
i = 0
while i<len(deger):
  print(deger[i])
  i=i+1
# Out:
# B
# A
# T
# M
# A
# N
#
# Ü
# N
# İ
# V
# E
# R
# S
# İ
# T
# E
# S
# İ

# %%
deger = "Batman"
i=len(deger)-1
while(i>-1):
  print(deger[i])
  i=i-1
# Out:
# n
# a
# m
# t
# a
# B

# %%
k_dizim = "Semih ASLAN"

print(k_dizim[0:5])
print(k_dizim[6:])
print(k_dizim[::])
print(k_dizim[::2])
print(k_dizim[::3])
print(*reversed(k_dizim))
print(k_dizim[::-1])
# Out:
# Semih
# ASLAN
# Semih ASLAN
# SmhALN
# SiAA
# N A L S A   h i m e S
# NALSA himeS

# %%
deger = "ahmet Semih güngör      "
print(deger.upper())
print(deger.lower())
print(deger.count("g"))
print(deger.strip("_"))
print(deger.title())
yenideger = deger.replace("ahmet","")
print(yenideger)
# Out:
# AHMET SEMIH GÜNGÖR
# ahmet semih güngör
# 2
# ahmet Semih güngör
# Ahmet Semih Güngör
#  Semih güngör
