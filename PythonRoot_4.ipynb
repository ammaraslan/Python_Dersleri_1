# %% [markdown]
# # Dosya İşlemleri
#
# ---

# %% [markdown]
# ## 1- Dosya Okuma & Açma İşlemleri

# %% [markdown]
# ### 1.1- Dosyayı Seçme
# Aşağıdaki yöntemle dosyamızı seçiyoruz ve işlem kipini(r-read) belirtiyoruz. Ayrıca karakter kodlamasınıda fonksiyona dahil edebiliriz.

# %%
dosya = open("ornek.txt","w")
dosya.write("Merhaba Derya\n")
dosya.write("Merhaba Semih\n")
dosya.write("Merhaba Taha\n")
dosya.close()

# %% [markdown]
# ### 1.2- Tüm Dosyayı Ekrana Yazdırma / read()

# %%
dosya = open("ornek.txt","r")
oku = dosya.read()
print(oku)
# Out:
# Merhaba Derya
# Merhaba Semih
# Merhaba Taha

# %%
dosya = open("ornek.txt","r")
oku = dosya.read(28)
print(oku)
# Out:
# Merhaba Derya
# Merhaba Semih

# %% [markdown]
# ### 1.3- Her Seferinde Sıradaki Satırı Ekrana Yazdırma / readline()

# %%
dosya = open("ornek.txt","r")
print(dosya.readline())
print(dosya.readline())
print(dosya.readline())
# Out:
# Merhaba Derya
#
# Merhaba Semih
#
# Merhaba Taha

# %% [markdown]
# 1.3- Dosyayı Satır Satır Döngüyle Ekrana Yazdırma / for

# %%
dosya  =open("ornek.txt","r")
i=1
for satir in dosya:
  print(i,". ",satir)
  i=i+1
# Out:
# 1 .  Merhaba Derya
#
# 2 .  Merhaba Semih
#
# 3 .  Merhaba Taha

# %% [markdown]
# ### 1.4- Dosyanın Her Satırını Diziye Eklemek / readlines()

# %%
dosya  =open("ornek.txt","r")
dizi = dosya.readlines()
print(dizi[2])
print(dizi[1])
# Out:
# Merhaba Taha
#
# Merhaba Semih

# %% [markdown]
# ## 2- Dosyaya Yazma İşlemleri
# Dosyalarımızı artık rahatça okuyabiliyoruz. Peki bu dosyalara istediğimiz verileri nasıl ekleyebiliriz? Bu sorunun cevabıda birazdan göreceğiniz gibi oldukça basit. Sadece dikkat etmeniz gereken tek nokta var ve buda dosyayı hangi kipte yazma moduna alacağınızdan başka birşey değil. İsterseniz hemen bu modlara bakıp örneklere geçelim.

# %% [markdown]
# ```
# Mod	ve Açıklama
# r:	Mevcut dosyayı okumak için açar, yoksa hata verir
# w:	Dosya yoksa oluşturur, varsa içeriği silerek sıfır dosya açar
# a:	Dosya yoksa oluşturur, varsa dosyanın sonunda imleçten başlayarak ekleme yapar
# r+:	Dosyayı hem okuma, hem yazma(w) modunda açar
# ```

# %% [markdown]
# ### 2.1- w Moduyla Dosyaya Veri Yazmak

# %%
dosya = open("bilgiler.txt","w")
dosya.write("Python Dosya İşlemleri\n")
dosya.write("Burası 2. satır oluyor artık\n")
dosya.write("3.satıra inmeden 2.satırın sonundan itibaren yazıyor\n")
dosya.close()

# %% [markdown]
# ### 2.1- a Moduyla Dosyaya Veri Yazmak

# %%
dosya = open("bilgiler.txt","a")
dosya.write("4.satır\n")
dosya.close()

# %% [markdown]
# ## 3- Dosyaları Kapatmak

# %%
dosya = open("bilgiler.txt","a")
dosya.close()

# %% [markdown]
# Kaynak: https://kerteriz.net/python-dosya-acma-okuma-yazma-ve-duzenleme-islemleri/

# %% [markdown]
# ## Uygulama 1 -
# Kullanıcı girişi yapan kod

# %%
import random

dosya = open("giris.txt","w")
dosya.writelines("ammaraslan@gmail.com"+" "+str(random.randrange(100000,9999999))+"\n")
dosya.write("ahmetsemih@gmail.com"+" "+str(random.randrange(100000,9999999))+"\n")
dosya.write("abdulkadir@gmail.com"+" "+str(random.randrange(100000,9999999))+"\n")
dosya.write("muhammed@gmail.com"+" "+str(random.randrange(100000,9999999))+"\n")
dosya.write("kadriye@gmail.com"+" "+str(random.randrange(100000,9999999)))
dosya.close()

# %%
kmail  = input("Lütfen mail adresinizi Giriniz: ")
ksiflkmre  = input("Lütfen sifre adresinizi Giriniz: ")
dosyaoku = open("giris.txt","r")

for x in dosyaoku:
  mail = x.split()[0]
  sifre  =x.split()[1]
  if(mail==kmail and sifre==ksifre):
    print("Hoş Geldiniz")
    break;
  else:
    print("Yanlış Geldiniz")
    break;
# Out:
# Lütfen mail adresinizi Giriniz: geag
# Lütfen sifre adresinizi Giriniz: 342
# Yanlış Geldiniz

# %%
dosya = open("ornek.txt","w")
dosya.write("Merhaba Derya\n")
dosya.write("Merhaba Semih\n")
dosya.write("Merhaba Taha\n")
dosya.write("Merhaba Abdulkadir\n")
dosya.write("Merhaba Ammar")
dosya.close()
dosyaoku = open("ornek.txt","r")
for satir in dosyaoku:
  print(satir)
dosya.close()
# Out:
# Merhaba Derya
#
# Merhaba Semih
#
# Merhaba Taha
#
# Merhaba Abdulkadir
#
# Merhaba Ammar

# %% [markdown]
# ## Uygulama 2

# %%
# dosya = open("ornek.txt","r")
# #print(dosya.read())
# DosyaListesi = dosya.readlines()
# print(DosyaListesi)
# print(DosyaListesi[1].upper())
for item in open("ornek.txt","r"):
    print(item.upper())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-3b38f8a5a427> in <module>()
#       4 # print(DosyaListesi)
#       5 # print(DosyaListesi[1].upper())
# ----> 6 for item in open("ornek.txt","r"):
#       7     print(item.upper())
#
# FileNotFoundError: [Errno 2] No such file or directory: 'ornek.txt'

# %% [markdown]
# ## Uygulama 3
# Öğrenci adında bir dosya oluşturup içerisinde aşağıdaki formatta  veriler kullanıcıdan alınıp eklenmesi istenmektedir. Bu bilgiler boşlukla ayrılacak ve her öğrenci için alt satıra inilecektir.
#
# 1.  Öğrenci Numarası
# 2.  Öğrenci Adı
# 3.  Vize Notu
# 4.  Final Notu
# 5.  Genel Not Ortalaması
#
# Genel Not Ortalamasını Vize*0,4 + Final*0,6 olarak yazan python kodunu yazınız.

# %%
    dosya = open("ogrenciler.txt","w")
    ogrNo = input("Lütfen Okul Numaranızı Giriniz")
    ogrAdi = input("Lütfen Adınızı Giriniz")
    ogrSoyadi = input("Lütfen Soyadı Giriniz")
    ogrVize = input("Lütfen Vizenizi Giriniz")
    ogrFinal = input("Lütfen Finalinizi Giriniz")
    ogrGNO = int(ogrVize)*0.4 +  int(ogrVize)*0.6
    dosya.writelines([ogrNo," ", ogrAdi," ", ogrSoyadi," ", ogrVize, " ", ogrFinal," ",str(ogrGNO)])
    dosya.close()
# Out:
# Lütfen Okul Numaranızı Giriniz1
# Lütfen Adınızı GirinizAmmar
# Lütfen Soyadı GirinizAslan
# Lütfen Vizenizi Giriniz100
# Lütfen Finalinizi Giriniz20

# %%
dosya = open("ogrenciler.txt","r")
print(dosya.readlines())
# Out:
# []
